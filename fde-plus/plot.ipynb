vt1 = [12.199454360119049, 16.831778368055556, 28.338209553571428, 32.45380989444444, 43.24273879166667, 73.83836928333334, 141.18848075, 269.48762625, 528.5155955, 533.3131585, 527.242307, 529.126097, 527.7285485, 526.880375, 530.541961, 528.401362, 529.0954785, 530.092968, 530.4597245, 531.0560385, 528.037385, 529.801841]
vt2 = [12.198648949999999, 16.589465483333335, 28.414127694444446, 33.039382, 42.02309234027778, 73.39396798611111, 139.31082078333333, 269.2066545, 528.176361, 1047.6992215, 1043.948084, 1042.423352, 1041.755482, 1055.2474625, 1042.350917, 1042.589808, 1043.666458, 1046.7190065, 1044.7137505, 1049.627717, 1071.6545365, 1050.747414]
vt3 = [11.688004652777778, 16.961432208333335, 27.431374287500002, 32.48019828333333, 42.03177814814815, 73.520034625, 139.49002715, 269.284676, 527.4593365, 1068.337204, 2217.9088315, 2222.9143, 2223.285853, 2227.235785, 2221.1709805, 2232.1448375, 2224.211622, 2223.183358, 2217.8393835, 2217.0001075, 2222.9290615, 2222.793539]

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Data size (#BLS12-381 field element)', fontsize=12)
ax1.set_ylabel('Time (ms)', fontsize=12)
ax1.plot(x_axis, pt1,marker="o", color=color,  label="Prover (R=256)")
ax1.plot(x_axis, pt2,marker="^", color=color,label="Prover (R=512)")
ax1.plot(x_axis, pt3,marker="s", color=color,label="Prover (R=1024)")
ax1.set_xscale('log', base=2)
ax1.tick_params(axis='y')
ax1.set_yscale('log',base=10)

## Adding a grid to the plot
ax1.set_axisbelow(True)
ax1.yaxis.grid(color='gray', linestyle='dashed')
ax1.xaxis.grid(color='gray', linestyle='dashed')

color = 'tab:blue'
# ax1.set_xlabel('Data size (#BLS12-381 field element)', fontsize=12)
# ax1.set_ylabel('Time (ms)', fontsize=12)
ax1.plot(x_axis, vt1,marker="o", color=color,  label="Verifier (R=256)")
ax1.plot(x_axis, vt2,marker="^", color=color,label="Verifier (R=512)")
ax1.plot(x_axis, vt3,marker="s", color=color,label="Verifier (R=1024)")
# ax1.set_xscale('log', base=2)
ax1.tick_params(axis='y')
# ax1.set_yscale('log',base=10)

proof_gen_ElGamal = [185.3590745, 96.33660292857144, 49.24739589166666, 27.85581397777778, 18.242110341111108, 11.97984247638889, 9.179191519047619, 9.600347827777776, 13.704928312244897, 14.117198407738096, 23.948108084444442, 25.756783725000002, 34.98453304166667, 46.75756940833333, 496.56952175, 539.0759845, 641.9243975, 814.94483, 1212.111492, 1994.6507145]
rangeProofsAndEncryptionTimes = [3171084/(2**(20-i)) for i in range(20)]
total_proof_gen_ElGamal = list(map(add,proof_gen_ElGamal,rangeProofsAndEncryptionTimes))
padding = [None] * 2
total_proof_gen_ElGamal += padding
total_proof_vfy_ElGamal = [14.031960473015873, 26.47698427222222, 32.06951591666667, 38.909525091666666, 46.78778227857143, 76.24852664583334, 140.30290805, 270.978584, 530.359108, 1053.6836585, 2214.4763845, 4417.865706, 8837.4587455, 17921.112061, 35442.012703, 70805.020974, 141743.7794955, 283081.6781005, 566311.361211, 1125801.959599]
total_proof_vfy_ElGamal += padding

color = 'tab:green'
ax1.plot(x_axis, total_proof_gen_ElGamal,marker="X",linestyle="dotted",color=color, label="FDE Prover")
ax1.plot(x_axis, total_proof_vfy_ElGamal,marker="X", linestyle="dotted",color='purple',  label="FDE Verifier")
ax1.tick_params(axis='y')

ax1.legend(loc='lower center', bbox_to_anchor=(0.66, .0), ncol=2, fancybox=True, shadow=True)
fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.savefig("./figures/proverVerifierTimes.pdf")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 49
#      46 total_proof_vfy_ElGamal += padding
#      48 color = 'tab:green'
# ---> 49 ax1.plot(x_axis, total_proof_gen_ElGamal,marker="X",linestyle="dotted",color=color, label="FDE Prover")
#      50 ax1.plot(x_axis, total_proof_vfy_ElGamal,marker="X", linestyle="dotted",color='purple',  label="FDE Verifier")
#      51 ax1.tick_params(axis='y')
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/site-packages/matplotlib/axes/_axes.py:1724, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1481 """
#    1482 Plot y versus x as lines and/or markers.
#    1483
#    (...)
#    1721 (``'green'``) or hex strings (``'#008000'``).
#    1722 """
#    1723 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1724 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1725 for line in lines:
# ...
